# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait

# %%
import requests

# API 엔드포인트 URL
url = 'https://kbland.kr/api/developmentplan/jigu/list'

# 쿼리 파라미터 설정
params = {
    'zoom': 17,
    'leftLon': 126.9933158,
    'rightLon': 127.0113402,
    'topLat': 37.5912256,
    'bottomLat': 37.5851554
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
}
# API 요청 보내기
response = requests.get(url, headers=headers, params=params)

# 응답 확인
# if response.status_code == 200:
#     data = response.json()  # JSON 데이터를 파싱
#     print(data)
# else:
#     print(f"Error: {response.status_code}")

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response.content
# Out:
# b'<!DOCTYPE html><html><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta http-equiv="Pragma" content="no-cache"><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"><meta http-equiv="Expires" content="0"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no"><meta name="naver-site-verification" content="ae0a8be277e0c89c5a52149c71bc40b152cb9aa3"><meta name="description" content="KB\xea\xb5\xad\xeb\xaf\xbc\xec\x9d\x80\xed\x96\x89\xec\x9d\xb4 \xeb\xa7\x8c\xeb\x93\xa0 \xeb\xb6\x80\xeb\x8f\x99\xec\x82\xb0 \xed\x94\x8c\xeb\x9e\xab\xed\x8f\xbc! \xeb\xa7\xa4\xeb\xac\xbc, \xec\x8b\x9c\xec\x84\xb8, \xec\x8b\xa4\xea\xb1\xb0\xeb\x9e\x98\xea\xb0\x80, \xeb\xb6\x84\xec\x96\x91, \xec\x84\xb8\xea\xb8\x88, AI\xec\x98\x88\xec\xb8\xa1\xec\x8b\x9c\xec\x84\xb8, \xeb\xb9\x8c\xeb\x9d\xbc\xec\x8b\x9c\xec\x84\xb8 \xeb\x93\xb1\xec\x9d\x84 \xed\x99\x95\xec\x9d\xb8\xed\x95\xb4\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94!"><meta name="facebook-domain-verification" content="nav8vl5sqcnk6aw7cmdvc7wgkaxpcf"><link rel="icon" href="favicon_kb.ico"><title>KB\xeb\xb6\x80\xeb\x8f\x99\xec\x82\xb0 - \xec\x95\x84\xed\x8c\x8c\xed\x8a\xb8 \xec\x8b\x9c\xec\x84\xb8, \xec\x8b\xa4\xea\xb1\xb0\xeb\x9e\x98\xea\xb0\x80, \xeb\xb6\x84\xec\x96\x91, \xeb\xb9\x8c\xeb\x9d\xbc\xec\x8b\x9c\xec\x84\xb8, \xec\x98\x88\xec\xb8\xa1\xec\x8b\x9c\xec\x84\xb8</title><base href="/"><script>window.$type="pc";\n\t\tconsole.log("________________",  window.$type);</script><script src="/libs/jquery/jquery-3.5.1.min.js"></script><script src="/libs/jquery/jquery.transform2d.js"></script><script src="/libs/jquery/jquery.transform3d.js"></script><script src="/libs/jquery-scrollbar/jquery.scrollbar.min.js"></script><script src="/libs/styles/TweenMax.js"></script><script src="/libs/KBSignCertPlus.js" charset="utf-8"></script><link type="text/css" rel="stylesheet" href="/libs/styles/bootstrap.min.css"><link type="text/css" rel="stylesheet" href="/libs/styles/bootstrap-vue.css"><link type="text/css" rel="stylesheet" href="/libs/styles/bootstrap-custom.css"><link type="text/css" rel="stylesheet" href="/libs/styles/toastmsg-default-theme.css"><link type="text/css" rel="stylesheet" href="/libs/styles/slick.css"><link type="text/css" rel="stylesheet" href="/libs/styles/vue-range-slider.css"><link type="text/css" rel="stylesheet" href="/common/styles/layout.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/ui.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/main.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/map.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/filters.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/webview.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/web.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/renew.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/renewmap.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/renewfilters.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/statistics.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/biz_common.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/myhome.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/dev.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/popup-plugin.css"><link type="text/css" rel="stylesheet" href="/libs/styles/vue2-datepicker.css"><link type="text/css" rel="stylesheet" href="/common/styles/photoviewer.css?version=1724714212478"><link type="text/css" rel="stylesheet" href="/common/styles/lan ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="no-cache" http-equiv="Pragma"/><meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/><meta content="0" http-equiv="Expires"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no" name="viewport"/><meta content="ae0a8be277e0c89c5a52149c71bc40b152cb9aa3" name="naver-site-verification"/><meta content="KB국민은행이 만든 부동산 플랫폼! 매물, 시세, 실거래가, 분양, 세금, AI예측시세, 빌라시세 등을 확인해보세요!" name="description"/><meta content="nav8vl5sqcnk6aw7cmdvc7wgkaxpcf" name="facebook-domain-verification"/><link href="favicon_kb.ico" rel="icon"/><title>KB부동산 - 아파트 시세, 실거래가, 분양, 빌라시세, 예측시세</title><base href="/"/><script>window.$type="pc";
# 		console.log("________________",  window.$type);</script><script src="/libs/jquery/jquery-3.5.1.min.js"></script><script src="/libs/jquery/jquery.transform2d.js"></script><script src="/libs/jquery/jquery.transform3d.js"></script><script src="/libs/jquery-scrollbar/jquery.scrollbar.min.js"></script><script src="/libs/styles/TweenMax.js"></script><script charset="utf-8" src="/libs/KBSignCertPlus.js"></script><link href="/libs/styles/bootstrap.min.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/bootstrap-vue.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/bootstrap-custom.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/toastmsg-default-theme.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/slick.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/vue-range-slider.css" rel="stylesheet" type="text/css"/><link href="/common/styles/layout.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/ui.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/main.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/map.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/filters.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/webview.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/web.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/renew.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/renewmap.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/renewfilters.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/statistics.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/biz_common.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/myhome.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/dev.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/popup-plugin.css" rel="stylesheet" type="text/css"/><link href="/libs/styles/vue2-datepicker.css" rel="stylesheet" type="text/css"/><link href="/common/styles/photoviewer.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/land_common.css?version=1724714212478" rel="stylesheet" type="text/css"/><link href="/common/styles/land_community.css?version=1724714212478" rel="stylesheet" type="text/css"/><style>#contents {
# 				z-index: 99999;
# 		}
# 		/*#contents > div { overflow: hidden; flex: 0 0 auto; width: 100% !important; max-width: 424px !important; }*/
# 		@media (max-width: 560px){
# 				#contents > div{max-width:100% !important}
# 		}
#
# 		@media (min-width: 560px){
# 				#contents > div{max-width:424px !important}
# 		}
#
# 		.bsLayer { width:423px }
#
# 		@media all and (max-width:1024px) {
# 				.web .SelectType .layerBotSheet { left:0 }
# 		}</style><!--[if !ie]>--><script language="javascript" src="https://static.kbdmp.com/ma/kb_v0.01.js"></script><script>if(window.ma) {
# 			// KB DMP
# 			ma.config('client_id', 'WA-0013');
# 			ma.config('isCookie', true);
# 		}</script><!--<![endif]--><style>.supportWrap{display:none}
# 		@media all and (-ms-high-contrast: none), (-ms-high-contrast: active) {
# 			.supportWrap{display:block;width:100%;height:100%}
# 			.supportWrap .supportCon{position:absolute;top:50%;left:0;width:100%;-webkit-transform:translateY(-50%);transform:translateY(-50%);text-align:center;font-size:20px}
# 		}</style><script>// stg, prod tag 구분
# 	    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer',/https:\/\/(www\.)?kbland.kr/.test(location.origin) ? 'GTM-TPMJRBV' : 'GTM-MTTHSDRM');</script><link href="/butler~pc.butler.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/chunk-2d0c49e8.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/chunk-2d0d6332.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/chunk-2d1756bf.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/chunk-77317cd4.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/chunk-77317cd4.6aa3fd8d3963726f6ca6.css" rel="prefetch"/><link href="/common~complex~honey~pc.common~pc.honey~pc.property~property.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/common~complex~honey~pc.common~pc.honey~pc.property~property.6c9087d8babdabddfa97.css" rel="prefetch"/><link href="/detail~pc.detail.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/event~pc.event.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/event~pc.event.fa884e52ba91282a3b17.css" rel="prefetch"/><link href="/honey~pc.common~pc.honey.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/honey~pc.common~pc.honey.93c0a1c50558603fb003.css" rel="prefetch"/><link href="/member~pc.member.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/member~pc.member.c354a0589c85a39ad580.css" rel="prefetch"/><link href="/pc.butler.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.butler.26ed70a093d540c8d211.css" rel="prefetch"/><link href="/pc.butler~pc.shhouse.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.butler~pc.shhouse.511288572ac830c2cf6d.css" rel="prefetch"/><link href="/pc.common.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.common.e604783b5add64490233.css" rel="prefetch"/><link href="/pc.common~pc.main.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.common~pc.myhouse.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.auth.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.auth.d81f3496a2d839817de5.css" rel="prefetch"/><link href="/pc.community.auth~pc.main.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.auth~pc.main.f7a0b162d9896b5beb61.css" rel="prefetch"/><link href="/pc.community.search.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.search.b5397aec2795df3427d2.css" rel="prefetch"/><link href="/pc.community.search~pc.community.user~pc.community.v2~pc.home~pc.selot.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.talk.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.talk.f35a29191bd7542b1870.css" rel="prefetch"/><link href="/pc.community.user.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.user.7051ea9c7d842a5d9487.css" rel="prefetch"/><link href="/pc.community.v2.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.community.v2.bd1f1bac14fa1a67856e.css" rel="prefetch"/><link href="/pc.complex.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.complex.956805f06bb57d9f1b0d.css" rel="prefetch"/><link href="/pc.detail.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.event.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.event.a52c3eaf2c209fd52d51.css" rel="prefetch"/><link href="/pc.home.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.home.78e2c8449c4edbaf2da9.css" rel="prefetch"/><link href="/pc.honey.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.honey.1defa9ee973710a10705.css" rel="prefetch"/><link href="/pc.honey~pc.main~pc.property.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.honey~pc.main~pc.property.b34f02f5a8c427ecbb5d.css" rel="prefetch"/><link href="/pc.main.1808e345c557ebf9aff9.js" rel="prefetch"/><link href="/pc.main.f34f6032ead5b1c07ed0.css" r ...
# 	wcs_add["wa"] = "c9a2b8eae419f0";
# 	// if(window.wcs){
# 	//   wcs_do();
# 	// }
# 	var agent = window.navigator.userAgent.toLowerCase();
# 	if (agent.indexOf('trident')!== -1 || agent.indexOf('msie') !== -1) {
# 		window.location = "microsoft-edge:" + window.location.origin;
# 		// window.close();
# 	}</script><script src="/chunk-common.1808e345c557ebf9aff9.js"></script><script src="/pc.1808e345c557ebf9aff9.js"></script></body></html>
